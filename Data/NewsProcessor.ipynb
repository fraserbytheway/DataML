# %%
import requests

url = "https://newsdata.io/api/1/sources"

parameters = {
    "apikey": "pub_a1ce978ac5274ca4b76cc60c5e4c1a4c",
    "country": "us,au,gb",
    "language": "en",
    "category": "breaking,politics,top,world,technology"
}

response = requests.get(url, params=parameters)

if response.status_code == 200:
    data = response.json()
    print(data)
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# {'status': 'success', 'totalResults': 100, 'results': [{'id': 'whyallanewsonline', 'name': 'The Whyalla News', 'url': 'https://whyallanewsonline.com.au', 'icon': 'https://n.bytvi.com/whyallanewsonline.png', 'priority': 2275572, 'description': 'The Whyalla News', 'category': ['top'], 'language': ['english'], 'country': ['australia'], 'total_article': 379, 'last_fetch': '2026-02-10 06:19:15'}, {'id': 'glasgowlive', 'name': 'Glasgowlive Co Uk', 'url': 'https://www.glasgowlive.co.uk', 'icon': 'https://n.bytvi.com/glasgowlive.png', 'priority': 120834, 'description': "Your companion to life in Scotland's biggest and best city. Covering News from Glasgow, sport, opinion and much more.", 'category': ['breaking', 'sports', 'top'], 'language': ['english'], 'country': ['united kingdom'], 'total_article': 26681, 'last_fetch': '2026-02-10 09:39:23'}, {'id': 'itemlive', 'name': 'Itemlive', 'url': 'https://itemlive.com', 'icon': 'https://n.bytvi.com/itemlive.png', 'priority': 27667, 'description': 'Serving the North Shore since 1877.', 'category': ['sports', 'lifestyle', 'entertainment', 'top', 'crime', 'education', 'politics', 'business'], 'language': ['english'], 'country': ['united states of america'], 'total_article': 8839, 'last_fetch': '2026-02-10 03:05:15'}, {'id': 'ucm_calpoly_edu', 'name': 'University Communications and Marketing', 'url': 'https://ucm.calpoly.edu', 'icon': 'https://n.bytvi.com/ucm_calpoly_edu.png', 'priority': 99999999, 'description': 'Learn by Doing', 'category': ['top'], 'language': ['english'], 'country': ['united states of america'], 'total_article': 0, 'last_fetch': '2026-02-09 10:58:34'}, {'id': 'apnews', 'name': 'Apnews', 'url': 'https://apnews.com', 'icon': 'https://n.bytvi.com/apnews.png', 'priority': 110, 'description': 'Read the latest headlines, breaking news, and videos at APNews.com, the definitive source for independent journalism from every corner of the globe.', 'category': ['top'], 'language': ['english'], 'country': ['united states of america'], 'total_article': 275735, 'last_fetch': '2026-02-10 09:00:12'}, {'id': 'news_sanfordhealth_org', 'name': 'Sanford Health News', 'url': 'https://news.sanfordhealth.org', 'icon': 'https://n.bytvi.com/news_sanfordhealth_org.png', 'priority': 99999999, 'description': 'Home', 'category': ['top', 'health'], 'language': ['english'], 'country': ['united states of america'], 'total_article': 0, 'last_fetch': '2026-02-09 16:25:25'}, {'id': 'marfapublicradio', 'name': 'Marfa Public Radio', 'url': 'https://marfapublicradio.org', 'icon': 'https://n.bytvi.com/marfapublicradio.jpeg', 'priority': 944730, 'description': 'Marfa Public Radio (MPR) is a non-profit radio station and media organization based in Marfa, Texas.', 'category': ['environment', 'education', 'top', 'health', 'other'], 'language': ['english'], 'country': ['united states of america'], 'total_article': 133, 'last_fetch': '2026-02-07 16:15:53'}, {'id': 'defensenews', 'name': 'Defense News', 'url': 'https://www.defensenews.com', 'icon': 'https://n.bytvi.com/defensenews.jpg', 'priority': 14961, 'description': 'Defense News is a global website and magazine about the politics, business and technology of defense, serving senior military and industry decision-makers.', 'category': ['politics', 'education', 'world', 'technology', 'business'], 'language': ['english'], 'country': ['united states of america'], 'total_article': 1941, 'last_fetch': '2026-02-10 09:34:00'}, {'id': 'pageone', 'name': 'Pageone Ng', 'url': 'http://pageone.ng', 'icon': 'https://n.bytvi.com/pageone.png', 'priority': 2911210, 'description': 'Breaking News on business, life, culture, politics and everything that matters to you.', 'category': ['world', 'sports', 'politics', 'top', 'business'], 'language': ['english'], 'country': ['united states of america'], 'total_article': 2169, 'last_fetch': '2024-09-23 03:52:35'}, {'id': 'mcalesternews', 'name': 'Mcalesternews', 'url': 'https://www.mcalesternews.com', 'icon': 'https://n.bytvi.com/mcalesterne ...
