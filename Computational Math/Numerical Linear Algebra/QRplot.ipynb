# %% [markdown]
# ### Curve Fitting Using Least Squares

# %%
import QRfactorisation

# %%
QRfactorisation.question2()
# Out:
# Least Squares Solution
#  [0.10387134]
# Residual: 20.73385631363815
# Least Squares Solution
#  [-4.20776497  1.72465452]
# Residual: 15.996513808775333
# Least Squares Solution
#  [-6.01391844  3.98234636 -0.45153837]
# Residual: 15.313868970333791
# Least Squares Solution
#  [-11.7037211   19.14278433  -8.18224851   1.03076135]
# Residual: 6.593989003982131
# Least Squares Solution
#  [-1.15864345e+01  1.85729632e+01 -7.64574747e+00  8.61746624e-01
#   1.69014728e-02]
# Residual: 6.587457644810583
# Least Squares Solution
#  [-11.27601699  16.02046397  -3.7923676   -1.24962437   0.49617758
#   -0.03834209]
# Residual: 6.531938724289114
# Least Squares Solution
#  [-11.10684742  13.73918227   1.2957136   -5.49662468   2.11801279
#   -0.32565453   0.01915416]
# Residual: 6.509481750258215
# Least Squares Solution
#  [-1.11949928e+01  1.56836211e+01 -4.76487103e+00  1.63664359e+00
#  -1.91347529e+00  8.50436910e-01 -1.51560316e-01  9.75511309e-03]
# Residual: 6.500282043289031
# ...
